# %%
# %run "../Wealth Based Policy/optimise.ipynb"
# %run "../Control Matrix Policy/optimise.ipynb"
# %run "../Control Matrix Policy/optimise_dynamic.ipynb"
# Out:
# ======================================================================
# OPTIMISING: sampler=cholesky | TIME_NODES=2 | WEALTH_NODES=2
# Iter 35/20,000  |  LR: 0.050000  |  Batch: 50,000 (stage 1/5)
# ======================================================================
# Cost:                   -0.934635
# Cost change:            0.00077693
# Best cost:              -0.935412
# Iters w/o improve:      1/60
# ----------------------------------------------------------------------
# Mean consumption:       $102,471
# Mean terminal wealth:   $1,196,829
# Bankruptcy rate:        25.65%
# Impoverishment density: 13.0610%
# Bankruptcy density:     10.3868%
# ----------------------------------------------------------------------
# Current policy (% bonds / % stocks):
#   Age  65: lowW 0.00%/100.00%  midW 32.09%/67.91%  highW 32.09%/67.91%
#   Age 100: lowW 0.00%/100.00%  midW 54.55%/45.45%  highW 54.55%/45.45%
# ======================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_25496\963171266.py:173
#     169                         policy_settings=policy,
#     170                     )
#     171
#     172                     cost = wealth_penalty.evaluate(wealth, consumption)
# --> 173                     cost.backward()
#     174                     project_policy_gradients_tangent_cone(policy)
#     175                     optimizer.step()
#     176
#
# File c:\Users\CallumDavidson\Code\MADS\.venv\Lib\site-packages\torch\_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File c:\Users\CallumDavidson\Code\MADS\.venv\Lib\site-packages\torch\autograd\__init__.py:379, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     374     retain_graph = create_graph
#     376 # The reason we repeat the same comment below is that
#     377 # some Python versions print out the first line of a multi-line function
#     378 # calls in the traceback and some print out the last line
# --> 379 _engine_run_backward(
#     380     tensors,
#     381     grad_tensors_,
#     382     retain_graph,
#     383     create_graph,
#     384     inputs_tuple,
#     385     allow_unreachable=True,
#     386     accumulate_grad=True,
#     387 )
#
# File c:\Users\CallumDavidson\Code\MADS\.venv\Lib\site-packages\torch\autograd\graph.py:882, in _engine_run_backward(t_outputs, *args, **kwargs)
#     879 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     881 try:
# --> 882     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     883         t_outputs, *args, **kwargs
#     884     )  # Calls into the C++ engine to run the backward pass
#     885 finally:
#     886     if attach_logging_hooks:
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 get_ipython().run_line_magic('run', '"../Wealth Based Policy/optimise.ipynb"')
#       2 get_ipython().run_line_magic('run', '"../Control Matrix Policy/optimise.ipynb"')
# ----> 3 get_ipython().run_line_magic('run', '"../Control Matrix Policy/optimise_dynamic.ipynb"')
#
# File ~\AppData\Local\Temp\ipykernel_25496\963171266.py:173
#     169                         policy_settings=policy,
#     170                     )
#     171
#     172                     cost = wealth_penalty.evaluate(wealth, consumption)
# --> 173                     cost.backward()
#     174                     project_policy_gradients_tangent_cone(policy)
#     175                     optimizer.step()
#     176
#
# File c:\Users\CallumDavidson\Code\MADS\.venv\Lib\site-packages\torch\_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File c:\Users\CallumDavidson\Code\MADS\.venv\Lib\site-packages\torch\autograd\__init__.py:379, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     374     retain_graph = create_graph
#     376 # The reason we repeat the same comment below is that
#     377 # some Python versions print out the first line of a multi-line function
#     378 # calls in the traceback and some print out the last line
# --> 379 _engine_run_backward(
#     380     tensors,
#     381     grad_tensors_,
#     382     retain_graph,
#     383     create_graph,
#     384     inputs_tuple,
#     385     allow_unreachable=True,
#     386     accumulate_grad=True,
#     387 )
#
# File c:\Users\CallumDavidson\Code\MADS\.venv\Lib\site-packages\torch\autograd\graph.py:882, in _engine_run_backward(t_outputs, *args, **kwargs)
#     879 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     881 try:
# --> 882     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     883         t_outputs, *args, **kwargs
#     884     )  # Calls into the C++ engine to run the backward pass
#     885 finally:
#     886     if attach_logging_hooks:
#
# KeyboardInterrupt:
