# %%
# %run "../Wealth Based Policy/optimise.ipynb"
# %run "../Control Matrix Policy/optimise.ipynb"
# %run "../Control Matrix Policy/optimise_dynamic.ipynb"
# Out:
# ...
# OPTIMISING: sampler=block_bootstrapped | TIME_NODE_COUNT=10 | WEALTH_NODE_COUNT=2
# Iteration 4,825/20,000 (24.1%)  |  LR: 0.000250  |  Batch: 400,000 (stage 5/5, lr_patience=40, min_iterations=None)
# ...
# Cost:                      -0.946704
# Cost change:               -0.00000000
# Best Cost:                 -0.946704
# Iterations w/o improve:    0/60
# ----------------------------------------------------------------------
# Mean consumption:          $360,990
# Mean terminal wealth:      $8,534,160
# Bankruptcy rate:           19.32%
# Impoverishment density:    9.6108%
# Bankruptcy density:        9.0570%
# ----------------------------------------------------------------------
# Current policy (% bonds/% stocks):
#   Age 65: lowW 0.00%/100.00%  midW 0.00%/31.60%  highW 0.00%/31.60%
#   Age 68: lowW 0.00%/100.00%  midW 0.00%/82.08%  highW 0.00%/82.08%
#   Age 72: lowW 0.00%/100.00%  midW 0.00%/100.00%  highW 0.00%/100.00%
# ...
